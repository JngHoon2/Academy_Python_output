# %% [markdown]
# # 작업 경로 변경 및 한글 인코딩

# %% [markdown]
# > ### 주피터 노트북 작업 경로 변경
# - 주피터 노트북 파일의 저장 위치를 파이썬 프로젝트 저장 폴더와 같게 한다.
# https://cafe.naver.com/freeflex/250

# %% [markdown]
# > ### 한글 깨짐 현상
# - 네이버 나눔고딕 폰트 다운로드한다.
#   https://hangeul.naver.com/font
# - 폰트 설치
# - 주피터 노트북에서 한글 폰트 설치 여부 확인후 [Ctrl + F] 찾기
# - NanumGothic 검색해서 있으면 정상 설치된 것임.
# https://itisik.tistory.com/114
# - 한글 폰트 설치했는데도 깨질 때
#   https://jinyes-tistory.tistory.com/70

# %% [markdown]
# - 설치된 한글 폰트를 주피터 노트북에 적용하기
# - 지정한 폰트가 모든 주피터 노트북에서 반영되도록 하는 방법
# - 설정파일에 약간의 수정을 해주어야 하므로, 설정파일의 위치를 먼저 알아야 한다.
#   아래의 코드를 통해 설정파일의 경로를 알아내자.
# - matplotlib 설정 파일 위치

# %%
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import matplotlib as mpl

# 설치된 한글 폰트 확인 #1
font_list = fm.findSystemFonts(fontpaths = None, fontext = 'ttf')
font_list[:]

print()

# 설치된 한글 폰트 확인 #2
f = [f.name for f in fm.fontManager.ttflist]
# print(f)

# 수정할 파일의 위치
print (mpl.matplotlib_fname())
# Out:
# D:\Anaconda\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %% [markdown]
# ![%ED%95%9C%EA%B8%80%EC%9D%B8%EC%BD%94%EB%94%A9%EC%88%98%EC%A0%95%ED%8C%8C%EC%9D%BC.jpg](attachment:%ED%95%9C%EA%B8%80%EC%9D%B8%EC%BD%94%EB%94%A9%EC%88%98%EC%A0%95%ED%8C%8C%EC%9D%BC.jpg)

# %% [markdown]
# ### 월별 판매 데이터 시각화

# %%
import numpy as np

sales = [1, 5, 7, 3, 7]
month = [3, 4, 5, 6, 7]

plt.plot(month, sales)
plt.show()

# %% [markdown]
# - 월 이름 변경

# %%
import matplotlib.pyplot as plt
import numpy as np

sales = [1, 5, 7, 3, 7]
month = ['3월', '4월', '5월', '6월', '7월']

plt.plot(month, sales)
plt.show()

# %%
import matplotlib
matplotlib.get_cachedir()
# Out:
# 'C:\\Users\\mycom\\.matplotlib'

# %%
# 기본 설정 읽기
import matplotlib.pyplot as plt

# size, family
print (plt.rcParams['font.size'] ) 
print (plt.rcParams['font.family'] )
# Out:
# 10.0
# ['NanumGothic']

# %% [markdown]
# > 월별 판매 실적

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 딕셔너리 형태의 key:value로 dataframe생성
raw_data = {'open': [11650, 11100, 11200, 11100, 11000],
            'high': [12100, 11800, 11200, 11100, 11150],
            'low': [11600, 11050, 10900, 10950, 10900],
            'close': [11900, 11600, 11000, 11100, 11050]}
# 행(row) 인덱스로 사용할 날짜 데이터 생성
date = ['20.02.29', '20.02.26', '20.02.25', '20.02.24', '20.02.23']  
# dataframe 생성(row 인덱스도 설정)
df = pd.DataFrame(raw_data, columns=['open', 'high', 'low', 'close'], index=date)  
df

plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.xlabel('X-축')
plt.ylabel('Y-label')
plt.show()
