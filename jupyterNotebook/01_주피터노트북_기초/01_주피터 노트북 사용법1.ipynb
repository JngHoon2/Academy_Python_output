# %% [markdown]
# # jupyter Notebook
#
# - 파이참-파이썬 프로젝트 제작시 코드 작성
# - 주피터 노트북은 하나의 보고서 작성에 따른 전체 과정을 기록하는 용도
# - 코랩은 머신러닝 딥러닝에서 탠서플로 환경들을 별도로 구축하지 않아도 코드 작성 및 테스트 할 수 있도록 구글에서 제공함.
# 	- 특히 머신러닝 쪽에서는 GPU를 이용해야 처리가 빠른데 일반 로컬에서는 Nvidia
# 	  그래픽 카드가 필요하고 그에 따른 cuda라든지 여러 설치 및 설정이 필요.
# 	- 구글에서는 개발자 편의를 위해 그와같은 환경을 온라인으로 제공.
# 	- 머신러닝 쪽 작업은 적어도 4GB이상의 데이터를 메모리에 올려 놓고 수만 건에서
# 	  수천만 건의 연산을 반복 수행해야 하기 때문에 GPU와같이 병렬처리 할 수 있는
# 	  고가의 그래픽 카드가 필요함.
# 	- 실무에서는 고가의 GPU도 여러 개 구축하여 모델을 학습하고 검증함.

# %% [markdown]
# ## 주피터 노트북 서버 실행
# ![launching_server.jpg](attachment:launching_server.jpg)

# %% [markdown]
# - 서버 구동 모습
# ![%EC%84%9C%EB%B2%84%20%EC%8B%A4%ED%96%89%20%ED%99%94%EB%A9%B4.jpg](attachment:%EC%84%9C%EB%B2%84%20%EC%8B%A4%ED%96%89%20%ED%99%94%EB%A9%B4.jpg)
# - 작업하는 동안 이 화면을 닫으면 안됨(서버가 shutdown됨)

# %% [markdown]
# ### 기본 사용 문법

# %%
## 주피터 노트북 사용법
#1. 셀이 초록색 : 편집모드- 셀을 클릭하면 코딩을 할 수 있는 상태로 바뀜
#  - 편집모드에서 [Esc]를 누르면 명령모드로 바뀐
#  - 편집모드에서 [b]를 누르면 바로 밑에 셀이 추가된다.
#2. 셀이 파란색 : 명령모드
#  - 명령모드에서 [M]을 누르면 Markdown 모드로 바뀜.
#  - 마크다운으로 바뀌면 in[숫자] 부분이 사라짐
#3. 셀 실행 : [Ctrl + Enter] : 실행후 현재 셀에 위치
#4. 셀 실행 : [Shift + Enter] : 실행후 다음 라인에 새로운 셀 생성
#5. 셀 추가 : 명령모드에서 [Insert > insert cell above]
#6. 셀별 라인넘버 : [View > toggle line number]
#7.

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("환영합니다")
# Out:
# 환영합니다

# %%
print("Hello My Friend")
# Out:
# Hello My Friend

# %%
import random
print(random.randint(1, 45))
# Out:
# 36

# %%
## 함수의 사용법이 궁금할 때는 뒤에 ? 1개 또는 더자세하게 알고 싶을땐 ?? 두개

# %%
random.randint?

# %%
random.randint??

# %%
num = 3

# %%
num *= 2

# %%
num += 4

# %%
print(num)
# Out:
# 10

# %% [markdown]
# ### 이미지 삽입
# > Markdown 모드에서 셀을 클릭하고 [Edit > insert image] 클릭

# %% [markdown]
# ![sample.jpg](attachment:sample.jpg)

# %% [markdown]
# ## 주피터 노트북 특징
# 1. 코드를 셀단위로 작성 및 실행
# 1. 마크다운을 통한 문서화
# 1. 그래프나 표등을 실시간으로 확인
# 1. html, pdf 등 파일로 저장

# %% [markdown]
# ## 파이썬 기본 문법

# %% [markdown]
# ## 시각화 예제 1 : 그래프
# - matplotlib을 이용하면 다양한 그래프를 그릴 수 있습니다.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()  # Create a figure containing a single axes.
ax.plot([1, 2, 3, 4], [1, 4, 2, 3]);  # Plot some data on the axes.

# %% [markdown]
# ## 시각화 예제 2 : 테이블
# - pandas는 매우 유용한 데이터분석 라이브러리입니다.

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

df = pd.DataFrame([[38.0, 2.0, 18.0, 22.0, 21, np.nan],[19, 439, 6, 452, 226,232]],
                  index=pd.Index(['Tumour (Positive)', 'Non-Tumour (Negative)'], name='Actual Label:'),
                  columns=pd.MultiIndex.from_product([['Decision Tree', 'Regression', 'Random'],['Tumour', 'Non-Tumour']], names=['Model:', 'Predicted:']))
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_69187">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Model:</th>
#       <th id="T_69187_level0_col0" class="col_heading level0 col0" colspan="2">Decision Tree</th>
#       <th id="T_69187_level0_col2" class="col_heading level0 col2" colspan="2">Regression</th>
#       <th id="T_69187_level0_col4" class="col_heading level0 col4" colspan="2">Random</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Predicted:</th>
#       <th id="T_69187_level1_col0" class="col_heading level1 col0" >Tumour</th>
#       <th id="T_69187_level1_col1" class="col_heading level1 col1" >Non-Tumour</th>
#       <th id="T_69187_level1_col2" class="col_heading level1 col2" >Tumour</th>
#       <th id="T_69187_level1_col3" class="col_heading level1 col3" >Non-Tumour</th>
#       <th id="T_69187_level1_col4" class="col_heading level1 col4" >Tumour</th>
# ...

# %% [markdown]
# ## 사이트 링크 거는 방법
#  - 구글 가기  편집시 가기 뒤에 스페이스 두 개 넣어주면 다음 줄에 출력됨.
#  [구글](https://www.google.com)

# %% [markdown]
# ## Html 문법 사용하는 방법
# - %%HTML
# - 여기에 youtube 주소 붙여넣기
# <iframe width="680" height="360" src="https://www.youtube.com/embed/CFnQ8rRQ8C0" title="[22/23 PL 10R] 브라이튼 vs 토트넘 손흥민 활약상" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
# %%HTML
# <iframe width="620" height="380" src="https://www.youtube.com/embed/KL1MIuBfWe0?list=PLU9-uwewPMe2AX9o9hFgv-nRvOcBdzvP5" title="최신 파이썬 코딩 무료 강의 - 5시간만 투자하면 개발자가 됩니다" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="620" height="380" src="https://www.youtube.com/embed/KL1MIuBfWe0?list=PLU9-uwewPMe2AX9o9hFgv-nRvOcBdzvP5" title="최신 파이썬 코딩 무료 강의 - 5시간만 투자하면 개발자가 됩니다" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## 셀번호를 연속적으로 다시 부여하는 방법
# - [Kernel > Restart & run all] 클릭
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 파일 저장 및 오픈
# - 현재 작업중인 파일의 저장위치 확인하는 방법

# %% [markdown]
# ![file_location-2.jpg](attachment:file_location-2.jpg)

# %% [markdown]
# - 저장한 주피터 노트북 파일을 열때는 [File > open]

# %% [markdown]
# ## 주피터 노트북 작업 경로 변경
# https://cafe.naver.com/freeflex/250
